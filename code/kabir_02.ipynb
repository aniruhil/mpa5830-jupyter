# %% [markdown]
# # Tutorial-02: Cleaning up and More Operations

# %% [markdown]
# We start as usual by loading up some libraries we will need.

# %%
import pandas as pd
import numpy as np

# %%
# The Food Establisment Inspection Data
df = pd.read_csv("https://data.boston.gov/dataset/03693648-2c62-4a2c-a4ec-48de2ee14e18/resource/4582bec6-2b4f-4f9e-bc55-cbaa73117f4c/download/tmpdbqq_szy.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(5)
# Out:
#                businessname dbaname         legalowner namelast namefirst  \
# 0  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 1  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 2  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 3  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 4  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
#
#    licenseno              issdttm              expdttm licstatus licensecat  \
# 0      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 1      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 2      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 3      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 4      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
#
#    ...             violdttm violstatus statusdate  \
# 0  ...  2013-02-15 12:19:42       Fail        NaN
# 1  ...  2013-02-15 12:19:42       Fail        NaN
# 2  ...  2013-02-15 12:19:42       Fail        NaN
# 3  ...  2013-02-15 12:19:42       Fail        NaN
# 4  ...  2013-02-15 12:19:42       Fail        NaN
#
#                                             comments              address  \
# 0                        Provide glass storage rack.  635   Hyde Park AVE
# 1  Provide dish rack over 3 bay sink to replace m...  635   Hyde Park AVE
# 2          Provide dish washer at ware washing area.  635   Hyde Park AVE
# 3                      Provide mop sink at basement.  635   Hyde Park AVE
# 4                 No hand sink at Bar Area  provide.  635   Hyde Park AVE
#
#          city state    zip property_id                       location
# 0  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 1  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 2  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 3  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 4  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
#
# [5 rows x 26 columns]

# %%
df_notna = df.dropna(how = 'all', subset = ['dbaname'])

# %%
df_notna.head(10)
# Out:
#                businessname dbaname         legalowner namelast namefirst  \
# 0  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 1  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 2  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 3  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 4  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 5  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 6  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 7  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 8  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 9  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
#
#    licenseno              issdttm              expdttm licstatus licensecat  \
# 0      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 1      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 2      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 3      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 4      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 5      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 6      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 7      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 8      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 9      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
#
#    ...             violdttm violstatus statusdate  \
# 0  ...  2013-02-15 12:19:42       Fail        NaN
# 1  ...  2013-02-15 12:19:42       Fail        NaN
# 2  ...  2013-02-15 12:19:42       Fail        NaN
# 3  ...  2013-02-15 12:19:42       Fail        NaN
# 4  ...  2013-02-15 12:19:42       Fail        NaN
# 5  ...  2013-02-15 12:19:42       Fail        NaN
# 6  ...  2013-03-21 14:48:33       Fail        NaN
# 7  ...  2013-10-24 11:18:12       Fail        NaN
# 8  ...  2013-10-24 11:18:12       Fail        NaN
# 9  ...  2013-10-24 11:18:12       Fail        NaN
#
#                                             comments              address  \
# 0                        Provide glass storage rack.  635   Hyde Park AVE
# 1  Provide dish rack over 3 bay sink to replace m...  635   Hyde Park AVE
# 2          Provide dish washer at ware washing area.  635   Hyde Park AVE
# 3                      Provide mop sink at basement.  635   Hyde Park AVE
# 4                 No hand sink at Bar Area  provide.  635   Hyde Park AVE
# 5  Provide door and finish miscellaneous storage ...  635   Hyde Park AVE
# 6          Provide dish washer at ware washing area.  635   Hyde Park AVE
# 7  Provide chefs thermometer for monitoring food ...  635   Hyde Park AVE
# 8             Replace heavily scorded cutting board.  635   Hyde Park AVE
# 9                 Dishmachine not operating  repair.  635   Hyde Park AVE
#
#          city state    zip property_id                       location
# 0  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 1  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 2  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 3  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 4  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 5  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 6  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 7  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 8  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 9  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
#
# [10 rows x 26 columns]

# %%
df['businessname'].value_counts()
# Out:
# Subway                         2865
# Dunkin Donuts                  2647
# Mcdonalds                      2076
# Dunkin' Donuts                 1892
# Au Bon Pain                    1649
#                                ...
# 88 Acres Foods                    1
# Uchef                             1
# Brighton Pharmacy                 1
# QINGPING GALLERY TEAHOUSE         1
# DOWNTOWN CROSSING ICE CREAM       1
# Name: businessname, Length: 7463, dtype: int64

# %%
df_notna = df.dropna(how = 'all', subset = ['businessname'])

# na.omit(df) ... drop the row if any column has any missing value

# %%
df_notna.head()
# Out:
#                businessname dbaname         legalowner namelast namefirst  \
# 0  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 1  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 2  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 3  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 4  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
#
#    licenseno              issdttm              expdttm licstatus licensecat  \
# 0      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 1      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 2      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 3      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 4      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
#
#    ...             violdttm violstatus statusdate  \
# 0  ...  2013-02-15 12:19:42       Fail        NaN
# 1  ...  2013-02-15 12:19:42       Fail        NaN
# 2  ...  2013-02-15 12:19:42       Fail        NaN
# 3  ...  2013-02-15 12:19:42       Fail        NaN
# 4  ...  2013-02-15 12:19:42       Fail        NaN
#
#                                             comments              address  \
# 0                        Provide glass storage rack.  635   Hyde Park AVE
# 1  Provide dish rack over 3 bay sink to replace m...  635   Hyde Park AVE
# 2          Provide dish washer at ware washing area.  635   Hyde Park AVE
# 3                      Provide mop sink at basement.  635   Hyde Park AVE
# 4                 No hand sink at Bar Area  provide.  635   Hyde Park AVE
#
#          city state    zip property_id                       location
# 0  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 1  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 2  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 3  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
# 4  Roslindale    MA  02131     77476.0  (42.278590000, -71.119440000)
#
# [5 rows x 26 columns]

# %% [markdown]
# We need to convert Dunkin' to Dunkin and this is done with .replace({"this":"with that"})

# %%
df['businessname'] = df['businessname'].replace({"Dunkin' Donuts":"Dunkin Donuts"})

# %%
# Did it work?
df['businessname'].value_counts()
# Out:
# Dunkin Donuts                         4539
# Subway                                2865
# Mcdonalds                             2076
# Au Bon Pain                           1649
# McDonald's                            1567
#                                       ...
# Bad Doughnut                             1
# Brazilian Bakery Specialties & Co        1
# The Quietfew                             1
# Corner Market                            1
# TB12 Performance & Recovery Center       1
# Name: businessname, Length: 7462, dtype: int64

# %%
df['businessname'] = df['businessname'].replace({"Mcdonalds":"McDonald's", "Mcdonald's":"McDonald's"})

# %%
df['businessname'].value_counts()
# Out:
# Dunkin Donuts                         4539
# McDonald's                            3643
# Subway                                2865
# Au Bon Pain                           1649
# Burger King                           1555
#                                       ...
# Bad Doughnut                             1
# Brazilian Bakery Specialties & Co        1
# The Quietfew                             1
# Corner Market                            1
# TB12 Performance & Recovery Center       1
# Name: businessname, Length: 7461, dtype: int64

# %% [markdown]
# We could do multiple replace statements in a single line of code.

# %%
df['businessname'] = df['businessname'].replace({"Dunkin' Donuts":"Dunkin Donuts", "Mcdonalds":"McDonald's"})

# %%
df['businessname'].value_counts()

# %% [markdown]
# Let us see what we can find for establishments in Lexington

# %%
df_lex = df[ df["city"] == "Lexington" ]

# %%
df_lex
# Out:
# Empty DataFrame
# Columns: [businessname, dbaname, legalowner, namelast, namefirst, licenseno, issdttm, expdttm, licstatus, licensecat, descript, result, resultdttm, violation, viollevel, violdesc, violdttm, violstatus, statusdate, comments, address, city, state, zip, property_id, location]
# Index: []
#
# [0 rows x 26 columns]

# %%
df_bos = df[ df['city'] == "Boston" ]

# %%
df_bos
# Out:
#                businessname dbaname    legalowner          namelast  \
# 178      1000 Degrees Pizza     NaN  KHOSLA VIPAN   Pasquriello LLC
# 196      1000 Degrees Pizza     NaN  KHOSLA VIPAN   Pasquriello LLC
# 206      1000 Degrees Pizza     NaN  KHOSLA VIPAN   Pasquriello LLC
# 207      1000 Degrees Pizza     NaN  KHOSLA VIPAN   Pasquriello LLC
# 208      1000 Degrees Pizza     NaN  KHOSLA VIPAN   Pasquriello LLC
# ...                     ...     ...           ...               ...
# 619244  Zumas Tex-Mex Grill     NaN           NaN  B B Kitchen Inc.
# 619245  Zumas Tex-Mex Grill     NaN           NaN  B B Kitchen Inc.
# 619246  Zumas Tex-Mex Grill     NaN           NaN  B B Kitchen Inc.
# 619247  Zumas Tex-Mex Grill     NaN           NaN  B B Kitchen Inc.
# 619248  Zumas Tex-Mex Grill     NaN           NaN  B B Kitchen Inc.
#
#                    namefirst  licenseno              issdttm  \
# 178     Kenneth Pasquariello     313440  2017-08-14 08:49:37
# 196     Kenneth Pasquariello     313440  2017-08-14 08:49:37
# 206     Kenneth Pasquariello     313440  2017-08-14 08:49:37
# 207     Kenneth Pasquariello     313440  2017-08-14 08:49:37
# 208     Kenneth Pasquariello     313440  2017-08-14 08:49:37
# ...                      ...        ...                  ...
# 619244            Cody Baker      26357  2012-02-22 10:46:22
# 619245            Cody Baker      26357  2012-02-22 10:46:22
# 619246            Cody Baker      26357  2012-02-22 10:46:22
# 619247            Cody Baker      26357  2012-02-22 10:46:22
# 619248            Cody Baker      26357  2012-02-22 10:46:22
#
#                     expdttm licstatus licensecat  ...             violdttm  \
# 178     2019-12-31 23:59:00  Inactive         FS  ...  2018-03-23 11:46:18
# 196     2019-12-31 23:59:00  Inactive         FS  ...  2018-03-23 11:46:18
# 206     2019-12-31 23:59:00  Inactive         FS  ...  2018-03-20 10:54:25
# 207     2019-12-31 23:59:00  Inactive         FS  ...  2018-03-20 10:54:25
# 208     2019-12-31 23:59:00  Inactive         FS  ...  2018-03-20 10:54:25
# ...                     ...       ...        ...  ...                  ...
# 619244  2020-12-31 23:59:00    Active         FS  ...  2017-06-06 12:11:55
# 619245  2020-12-31 23:59:00    Active         FS  ...  2017-06-06 12:11:55
# 619246  2020-12-31 23:59:00    Active         FS  ...  2017-06-06 12:11:55
# 619247  2020-12-31 23:59:00    Active         FS  ...  2017-06-06 12:11:55
# 619248  2020-12-31 23:59:00    Active         FS  ...  2017-06-06 12:11:55
#
#        violstatus           statusdate  \
# 178          Pass  2018-03-23 16:15:45
# 196          Pass  2018-03-23 16:15:45
# 206          Fail                  NaN
# 207          Fail                  NaN
# 208          Fail                  NaN
# ...           ...                  ...
# 619244       Fail                  NaN
# 619245       Fail                  NaN
# 619246       Pass  2017-06-06 15:14:59
# 619247       Fail                  NaN
# 619248       Fail                  NaN
#
#                                                  comments  \
# 178      One staff person without hair restraint. Provide
# 196     Caked on food debris on can opener blade. Clea...
# 206      One staff person without hair restraint. Provide
# 207     Caked on food debris on can opener blade. Clea...
# 208     Menu was redesigned allergy statement was remo...
# ...                                                   ...
# 619244  Waste water from leaking pipe pooling on floor...
# 619245  Leaking waste pipe in wall behind cookline per...
# 619246  Leaking waste drain behind cookline per disuss...
# 619247  Waste water from leaking pipe pooling on floor...
# 619248  Waste water from leaking pipe behind wall. Cle...
#
#                                  address    city state    zip property_id  \
# 178                        55   Court ST  Boston    MA  02108    156226.0
# 196                        55   Court ST  Boston    MA  02108    156226.0
# 206                        55   Court ST  Boston    MA  02108    156226.0
# 207                        55   Court ST  Boston    MA  02108    156226.0
# 208                        55   Court ST  Boston    MA  02108    156226.0
# ...                                  ...     ...   ...    ...         ...
# 619244  100-199   Faneuil Hall Market PL  Boston    MA  02109         NaN
# 619245  100-199   Faneuil Hall Market PL  Boston    MA  02109         NaN
# 619246  100-199   Faneuil Hall Market PL  Boston    MA  02109         NaN
# 619247  100-199   Faneuil Hall Market PL  Boston    MA  02109         NaN
# 619248  100-199   Faneuil Hall Market PL  Boston    MA  02109         NaN
#
#                              location
# 178     (42.359227000, -71.058878000)
# 196     (42.359227000, -71.058878000)
# 206     (42.359227000, -71.058878000)
# 207     (42.359227000, -71.058878000)
# 208     (42.359227000, -71.058878000)
# ...                               ...
# 619244                            NaN
# 619245                            NaN
# 619246                            NaN
# 619247                            NaN
# 619248                            NaN
#
# [234286 rows x 26 columns]

# %%
df
# Out:
#                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 619363       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 619364       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 619365       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 619366       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 619367       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# 0        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# 1        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# 2        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# 3        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# 4        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# ...          ...        ...                  ...                  ...
# 619363      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
# 619364      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
# 619365      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
# 619366      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
# 619367      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
#
#        licstatus licensecat  ...             violdttm violstatus  \
# 0         Active         FS  ...  2013-02-15 12:19:42       Fail
# 1         Active         FS  ...  2013-02-15 12:19:42       Fail
# 2         Active         FS  ...  2013-02-15 12:19:42       Fail
# 3         Active         FS  ...  2013-02-15 12:19:42       Fail
# 4         Active         FS  ...  2013-02-15 12:19:42       Fail
# ...          ...        ...  ...                  ...        ...
# 619363    Active         FT  ...  2019-10-04 10:47:22       Pass
# 619364    Active         FT  ...  2020-03-11 13:53:43       Pass
# 619365    Active         FT  ...  2020-03-11 13:53:43       Pass
# 619366    Active         FT  ...  2020-03-11 13:53:43       Pass
# 619367    Active         FT  ...  2020-03-11 13:53:43       Pass
#
#                  statusdate  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 619363  2019-10-07 08:34:04
# 619364  2020-03-13 08:40:41
# 619365  2020-03-13 08:40:41
# 619366  2020-03-13 08:40:41
# 619367  2020-03-13 08:40:41
#
#                                                  comments  \
# 0                             Provide glass storage rack.
# 1       Provide dish rack over 3 bay sink to replace m...
# 2               Provide dish washer at ware washing area.
# 3                           Provide mop sink at basement.
# 4                      No hand sink at Bar Area  provide.
# ...                                                   ...
# 619363  They do not have a high temp thermometer for t...
# 619364  No label on yogurt cups in grab n go case.  Sl...
# 619365               Heavy scorded cutting board. Replace
# 619366  Bulk container blocking access to handsink .Ha...
# 619367                       No soap at handsink. Provide
#
#                     address         city state    zip property_id  \
# 0       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# 1       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# 2       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# 3       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# 4       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# ...                     ...          ...   ...    ...         ...
# 619363        219   Main ST  Charlestown    MA  02129     88457.0
# 619364        219   Main ST  Charlestown    MA  02129     88457.0
# 619365        219   Main ST  Charlestown    MA  02129     88457.0
# 619366        219   Main ST  Charlestown    MA  02129     88457.0
# 619367        219   Main ST  Charlestown    MA  02129     88457.0
#
#                              location
# 0       (42.278590000, -71.119440000)
# 1       (42.278590000, -71.119440000)
# 2       (42.278590000, -71.119440000)
# 3       (42.278590000, -71.119440000)
# 4       (42.278590000, -71.119440000)
# ...                               ...
# 619363  (42.376540000, -71.065421000)
# 619364  (42.376540000, -71.065421000)
# 619365  (42.376540000, -71.065421000)
# 619366  (42.376540000, -71.065421000)
# 619367  (42.376540000, -71.065421000)
#
# [619368 rows x 26 columns]

# %%
df_bos.head(5)
# Out:
#            businessname dbaname    legalowner         namelast  \
# 178  1000 Degrees Pizza     NaN  KHOSLA VIPAN  Pasquriello LLC
# 196  1000 Degrees Pizza     NaN  KHOSLA VIPAN  Pasquriello LLC
# 206  1000 Degrees Pizza     NaN  KHOSLA VIPAN  Pasquriello LLC
# 207  1000 Degrees Pizza     NaN  KHOSLA VIPAN  Pasquriello LLC
# 208  1000 Degrees Pizza     NaN  KHOSLA VIPAN  Pasquriello LLC
#
#                 namefirst  licenseno              issdttm  \
# 178  Kenneth Pasquariello     313440  2017-08-14 08:49:37
# 196  Kenneth Pasquariello     313440  2017-08-14 08:49:37
# 206  Kenneth Pasquariello     313440  2017-08-14 08:49:37
# 207  Kenneth Pasquariello     313440  2017-08-14 08:49:37
# 208  Kenneth Pasquariello     313440  2017-08-14 08:49:37
#
#                  expdttm licstatus licensecat  ...             violdttm  \
# 178  2019-12-31 23:59:00  Inactive         FS  ...  2018-03-23 11:46:18
# 196  2019-12-31 23:59:00  Inactive         FS  ...  2018-03-23 11:46:18
# 206  2019-12-31 23:59:00  Inactive         FS  ...  2018-03-20 10:54:25
# 207  2019-12-31 23:59:00  Inactive         FS  ...  2018-03-20 10:54:25
# 208  2019-12-31 23:59:00  Inactive         FS  ...  2018-03-20 10:54:25
#
#     violstatus           statusdate  \
# 178       Pass  2018-03-23 16:15:45
# 196       Pass  2018-03-23 16:15:45
# 206       Fail                  NaN
# 207       Fail                  NaN
# 208       Fail                  NaN
#
#                                               comments        address    city  \
# 178   One staff person without hair restraint. Provide  55   Court ST  Boston
# 196  Caked on food debris on can opener blade. Clea...  55   Court ST  Boston
# 206   One staff person without hair restraint. Provide  55   Court ST  Boston
# 207  Caked on food debris on can opener blade. Clea...  55   Court ST  Boston
# 208  Menu was redesigned allergy statement was remo...  55   Court ST  Boston
#
#     state    zip property_id                       location
# 178    MA  02108    156226.0  (42.359227000, -71.058878000)
# 196    MA  02108    156226.0  (42.359227000, -71.058878000)
# 206    MA  02108    156226.0  (42.359227000, -71.058878000)
# 207    MA  02108    156226.0  (42.359227000, -71.058878000)
# 208    MA  02108    156226.0  (42.359227000, -71.058878000)
#
# [5 rows x 26 columns]

# %% [markdown]
# What establishments have the most violations in Boston?

# %%
df_bos['businessname'].value_counts()
# Out:
# McDonald's                        1402
# Dunkin Donuts                     1397
# Au Bon Pain                       1237
# Durgin Park Restaurant             864
# Subway                             779
#                                   ...
# Urban Express Chelet                 1
# Marilyn's Jam Session                1
# PETE'S DOCKSIDE                      1
# Cosmica @ the Revolution Hotel       1
# Rolling Gyros                        1
# Name: businessname, Length: 3140, dtype: int64

# %% [markdown]
# What legal owner seems to have the most violations?

# %%
df['legalowner'].value_counts()
# Out:
#                                         35567
# MCCOY RICHARD                            2421
# GILLETTE CAFETERIA EDWARD C. COLEMAN     1880
# PETER LUU  PRES.                         1800
# JACK LYONS  MANAGER                      1594
#                                         ...
# ANN VO                                      1
# JAMES HOOK & CO.                            1
# FRIEDBERG WILLIAM                           1
# OMAR ABU-HASAN                              1
# ALAA KHAMIS                                 1
# Name: legalowner, Length: 2665, dtype: int64

# %% [markdown]
# Now it might a good idea to dig into this McCoy dude.

# %%
df_mccoy = df[ df['legalowner'] == "MCCOY RICHARD" ]

# %%
df_mccoy['businessname'].value_counts()
# Out:
# BOURBON ST. CAFE        494
# THAI ACCENT             365
# METRO SUBWAY INC.       206
# Indian Entree's         189
# SUSHI TIME              171
# SALSAS MEXICAN GRILL    164
# SBARROS PIZZA           162
# WONGS                   150
# Sarku Japan             110
# McDonald's               87
# Dunkin Donuts            65
# Wong's of Boston         62
# Tasty BBQ                58
# Xian Rougamo             56
# VOUROS RESTAURANT        43
# Sulgrave News            24
# Sweet Tooth Boston       11
# Nina Baker Shop           3
# SULGRAVE  INC.            1
# Name: businessname, dtype: int64

# %%
df_check1 = df[ df['businessname'] == "Sulgrave News"]
df_check2 = df[ df['businessname'] == "SULGRAVE  INC."]

# %%
df_check1
# Out:
#          businessname          dbaname         legalowner            namelast  \
# 474042  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 474077  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 474116  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 474589  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 474625  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 474757  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 517226  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 517282  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 517283  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 517303  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 517304  Sulgrave News              NaN                NaN  AMM BUSINESS CORP.
# 517305  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517306  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517307  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517308  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517309  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517310  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517311  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517312  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517313  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517314  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517315  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517316  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517317  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517318  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517319  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517320  Sulgrave News              NaN  BEAL S MAXWELL TS              SAFWAN
# 517321  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517322  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517323  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517324  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517325  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517326  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517327  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517328  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517329  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517330  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517331  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517332  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517333  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517334  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517335  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517336  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517337  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517338  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517339  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517340  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517341  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517342  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517343  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
# 517344  Sulgrave News  AMM Corporation      MCCOY RICHARD               Ahmad
#
#        namefirst  licenseno              issdttm              expdttm  \
# 474042                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 474077                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 474116                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 474589                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 474625                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 474757                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 517226                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 517282                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 517283                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 517303                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 517304                68208  2012-02-06 13:20:12  2018-12-31 23:59:00
# 517305     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517306     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517307     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517308     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517309     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517310     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517311     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517312     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517313     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517314     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517315     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517316     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517317     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517318     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517319     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517320     NABIL      22663  2012-06-14 09:39:27  2011-12-31 23:59:00
# 517321     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517322     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517323     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517324     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517325     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517326     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517327     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517328     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517329     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517330     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517331     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517332     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517333     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517334     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517335     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517336     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517337     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517338     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517339     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517340     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517341     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517342     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517343     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
# 517344     Altaf      17602  2011-12-12 15:18:55  2020-12-31 23:59:00
#
#        licstatus licensecat  ...             violdttm violstatus  \
# 474042  Inactive         RF  ...                             NaN
# 474077  Inactive         RF  ...                             NaN
# 474116  Inactive         RF  ...                             NaN
# 474589  Inactive         RF  ...                             NaN
# 474625  Inactive         RF  ...                             NaN
# 474757  Inactive         RF  ...                             NaN
# 517226  Inactive         RF  ...                             NaN
# 517282  Inactive         RF  ...                             NaN
# 517283  Inactive         RF  ...                             NaN
# 517303  Inactive         RF  ...  2015-08-17 12:52:33       Fail
# 517304  Inactive         RF  ...  2015-08-17 12:52:33       Fail
# 517305  Inactive         RF  ...  2009-06-25 15:03:10       Fail
# 517306  Inactive         RF  ...  2009-06-25 15:03:10       Fail
# 517307  Inactive         RF  ...  2009-06-25 15:03:10       Fail
# 517308  Inactive         RF  ...  2007-10-11 14:46:28       Fail
# 517309  Inactive         RF  ...  2007-10-11 14:46:28       Fail
# 517310  Inactive         RF  ...  2009-07-01 15:13:14       Fail
# 517311  Inactive         RF  ...  2009-07-01 15:13:14       Fail
# 517312  Inactive         RF  ...  2009-07-01 15:13:14       Fail
# 517313  Inactive         RF  ...                             NaN
# 517314  Inactive         RF  ...                             NaN
# 517315  Inactive         RF  ...                             NaN
# 517316  Inactive         RF  ...  2009-07-13 15:22:17       Pass
# 517317  Inactive         RF  ...  2009-07-13 15:22:17       Pass
# 517318  Inactive         RF  ...  2009-07-13 15:22:17       Pass
# 517319  Inactive         RF  ...                             NaN
# 517320  Inactive         RF  ...                             NaN
# 517321  Inactive         RF  ...                             NaN
# 517322  Inactive         RF  ...  2012-06-05 14:10:00       Fail
# 517323  Inactive         RF  ...  2012-06-05 14:10:00       Fail
# 517324  Inactive         RF  ...  2012-06-05 14:10:00       Fail
# 517325  Inactive         RF  ...  2012-06-05 14:10:00       Fail
# 517326  Inactive         RF  ...  2012-06-05 14:10:00       Fail
# 517327  Inactive         RF  ...  2012-06-05 14:10:00       Fail
# 517328  Inactive         RF  ...  2009-08-21 08:41:56       Fail
# 517329  Inactive         RF  ...  2017-07-28 14:15:17       Fail
# 517330  Inactive         RF  ...                             NaN
# 517331  Inactive         RF  ...                             NaN
# 517332  Inactive         RF  ...                             NaN
# 517333  Inactive         RF  ...                             NaN
# 517334  Inactive         RF  ...                             NaN
# 517335  Inactive         RF  ...                             NaN
# 517336  Inactive         RF  ...  2012-08-23 11:16:35       Pass
# 517337  Inactive         RF  ...  2012-08-23 11:16:35       Pass
# 517338  Inactive         RF  ...  2012-08-23 11:16:35       Pass
# 517339  Inactive         RF  ...  2012-08-23 11:16:35       Pass
# 517340  Inactive         RF  ...  2012-08-23 11:16:35       Pass
# 517341  Inactive         RF  ...  2013-11-20 11:06:30       Pass
# 517342  Inactive         RF  ...                             NaN
# 517343  Inactive         RF  ...                             NaN
# 517344  Inactive         RF  ...                             NaN
#
#                  statusdate  \
# 474042                  NaN
# 474077                  NaN
# 474116                  NaN
# 474589                  NaN
# 474625                  NaN
# 474757                  NaN
# 517226                  NaN
# 517282                  NaN
# 517283                  NaN
# 517303                  NaN
# 517304                  NaN
# 517305                  NaN
# 517306                  NaN
# 517307                  NaN
# 517308                  NaN
# 517309                  NaN
# 517310                  NaN
# 517311                  NaN
# 517312                  NaN
# 517313                  NaN
# 517314                  NaN
# 517315                  NaN
# 517316  2009-07-13 15:22:17
# 517317  2009-07-13 15:22:17
# 517318  2009-07-13 15:22:17
# 517319                  NaN
# 517320                  NaN
# 517321                  NaN
# 517322                  NaN
# 517323                  NaN
# 517324                  NaN
# 517325                  NaN
# 517326                  NaN
# 517327                  NaN
# 517328                  NaN
# 517329                  NaN
# 517330                  NaN
# 517331                  NaN
# 517332                  NaN
# 517333                  NaN
# 517334                  NaN
# 517335                  NaN
# 517336  2012-08-23 15:40:55
# 517337  2012-08-23 15:40:55
# 517338  2012-08-23 15:40:55
# 517339  2012-08-23 15:40:55
# 517340  2012-08-23 15:40:55
# 517341  2013-11-20 15:42:01
# 517342                  NaN
# 517343                  NaN
# 517344                  NaN
#
#                                                  comments  \
# 474042
# 474077
# 474116
# 474589
# 474625
# 474757
# 517226
# 517282
# 517283
# 517303  Floors throughout and along walls with visible...
# 517304     Properly organize back area to reduce clutter.
# 517305   Keep all potato chips inside store while  off...
# 517306            Provide proper storage of wiping cloths
# 517307                         keep doors to store closed
# 517308                  provide thermometer ir Pepsi Case
# 517309                               clear lower cabinets
# 517310   Keep all potato chips inside store while  off...
# 517311            Provide proper storage of wiping cloths
# 517312                         keep doors to store closed
# 517313
# 517314
# 517315
# 517316   Keep all potato chips inside store while  off...
# 517317            Provide proper storage of wiping cloths
# 517318                         keep doors to store closed
# 517319
# 517320
# 517321
# 517322  There are boxes of lettuce with "keep refriger...
# 517323  The prep table is adjacent to the wash side of...
# 517324            The slicer is soiled.  Clean to remove.
# 517325  There is no soap at the handsink in the prep a...
# 517326  The tile floor is in disrepair.  Repair missin...
# 517327  There is a hole in the wall under the sink.  R...
# 517328                      Clean floor of storage Closet
# 517329  Storage shelves used for bags of chips visibly...
# 517330
# 517331
# 517332
# 517333
# 517334
# 517335
# 517336  The prep table is adjacent to the wash side of...
# 517337            The slicer is soiled.  Clean to remove.
# 517338  There is no soap at the handsink in the prep a...
# 517339  The tile floor is in disrepair.  Repair missin...
# 517340  There is a hole in the wall under the sink.  R...
# 517341  There are boxes of lettuce with "keep refriger...
# 517342
# 517343
# 517344
#
#                     address    city state    zip property_id  \
# 474042          6   Milk ST  Boston    MA  02108    157508.0
# 474077          6   Milk ST  Boston    MA  02108    157508.0
# 474116          6   Milk ST  Boston    MA  02108    157508.0
# 474589          6   Milk ST  Boston    MA  02108    157508.0
# 474625          6   Milk ST  Boston    MA  02108    157508.0
# 474757          6   Milk ST  Boston    MA  02108    157508.0
# 517226          6   Milk ST  Boston    MA  02108    157508.0
# 517282          6   Milk ST  Boston    MA  02108    157508.0
# 517283          6   Milk ST  Boston    MA  02108    157508.0
# 517303          6   Milk ST  Boston    MA  02108    157508.0
# 517304          6   Milk ST  Boston    MA  02108    157508.0
# 517305     85   Franklin ST  Boston    MA  02110     60687.0
# 517306     85   Franklin ST  Boston    MA  02110     60687.0
# 517307     85   Franklin ST  Boston    MA  02110     60687.0
# 517308     85   Franklin ST  Boston    MA  02110     60687.0
# 517309     85   Franklin ST  Boston    MA  02110     60687.0
# 517310     85   Franklin ST  Boston    MA  02110     60687.0
# 517311     85   Franklin ST  Boston    MA  02110     60687.0
# 517312     85   Franklin ST  Boston    MA  02110     60687.0
# 517313     85   Franklin ST  Boston    MA  02110     60687.0
# 517314     85   Franklin ST  Boston    MA  02110     60687.0
# 517315     85   Franklin ST  Boston    MA  02110     60687.0
# 517316     85   Franklin ST  Boston    MA  02110     60687.0
# 517317     85   Franklin ST  Boston    MA  02110     60687.0
# 517318     85   Franklin ST  Boston    MA  02110     60687.0
# 517319     85   Franklin ST  Boston    MA  02110     60687.0
# 517320     85   Franklin ST  Boston    MA  02110     60687.0
# 517321  417   Washington ST  Boston    MA  02108    157146.0
# 517322  417   Washington ST  Boston    MA  02108    157146.0
# 517323  417   Washington ST  Boston    MA  02108    157146.0
# 517324  417   Washington ST  Boston    MA  02108    157146.0
# 517325  417   Washington ST  Boston    MA  02108    157146.0
# 517326  417   Washington ST  Boston    MA  02108    157146.0
# 517327  417   Washington ST  Boston    MA  02108    157146.0
# 517328  417   Washington ST  Boston    MA  02108    157146.0
# 517329  417   Washington ST  Boston    MA  02108    157146.0
# 517330  417   Washington ST  Boston    MA  02108    157146.0
# 517331  417   Washington ST  Boston    MA  02108    157146.0
# 517332  417   Washington ST  Boston    MA  02108    157146.0
# 517333  417   Washington ST  Boston    MA  02108    157146.0
# 517334  417   Washington ST  Boston    MA  02108    157146.0
# 517335  417   Washington ST  Boston    MA  02108    157146.0
# 517336  417   Washington ST  Boston    MA  02108    157146.0
# 517337  417   Washington ST  Boston    MA  02108    157146.0
# 517338  417   Washington ST  Boston    MA  02108    157146.0
# 517339  417   Washington ST  Boston    MA  02108    157146.0
# 517340  417   Washington ST  Boston    MA  02108    157146.0
# 517341  417   Washington ST  Boston    MA  02108    157146.0
# 517342  417   Washington ST  Boston    MA  02108    157146.0
# 517343  417   Washington ST  Boston    MA  02108    157146.0
# 517344  417   Washington ST  Boston    MA  02108    157146.0
#
#                              location
# 474042  (42.356865000, -71.058188000)
# 474077  (42.356865000, -71.058188000)
# 474116  (42.356865000, -71.058188000)
# 474589  (42.356865000, -71.058188000)
# 474625  (42.356865000, -71.058188000)
# 474757  (42.356865000, -71.058188000)
# 517226  (42.356865000, -71.058188000)
# 517282  (42.356865000, -71.058188000)
# 517283  (42.356865000, -71.058188000)
# 517303  (42.356865000, -71.058188000)
# 517304  (42.356865000, -71.058188000)
# 517305  (42.355180000, -71.057900000)
# 517306  (42.355180000, -71.057900000)
# 517307  (42.355180000, -71.057900000)
# 517308  (42.355180000, -71.057900000)
# 517309  (42.355180000, -71.057900000)
# 517310  (42.355180000, -71.057900000)
# 517311  (42.355180000, -71.057900000)
# 517312  (42.355180000, -71.057900000)
# 517313  (42.355180000, -71.057900000)
# 517314  (42.355180000, -71.057900000)
# 517315  (42.355180000, -71.057900000)
# 517316  (42.355180000, -71.057900000)
# 517317  (42.355180000, -71.057900000)
# 517318  (42.355180000, -71.057900000)
# 517319  (42.355180000, -71.057900000)
# 517320  (42.355180000, -71.057900000)
# 517321  (42.355830000, -71.060400000)
# 517322  (42.355830000, -71.060400000)
# 517323  (42.355830000, -71.060400000)
# 517324  (42.355830000, -71.060400000)
# 517325  (42.355830000, -71.060400000)
# 517326  (42.355830000, -71.060400000)
# 517327  (42.355830000, -71.060400000)
# 517328  (42.355830000, -71.060400000)
# 517329  (42.355830000, -71.060400000)
# 517330  (42.355830000, -71.060400000)
# 517331  (42.355830000, -71.060400000)
# 517332  (42.355830000, -71.060400000)
# 517333  (42.355830000, -71.060400000)
# 517334  (42.355830000, -71.060400000)
# 517335  (42.355830000, -71.060400000)
# 517336  (42.355830000, -71.060400000)
# 517337  (42.355830000, -71.060400000)
# 517338  (42.355830000, -71.060400000)
# 517339  (42.355830000, -71.060400000)
# 517340  (42.355830000, -71.060400000)
# 517341  (42.355830000, -71.060400000)
# 517342  (42.355830000, -71.060400000)
# 517343  (42.355830000, -71.060400000)
# 517344  (42.355830000, -71.060400000)
#
# [51 rows x 26 columns]

# %%
df_check2
# Out:
#           businessname dbaname     legalowner namelast namefirst  licenseno  \
# 517302  SULGRAVE  INC.     NaN  MCCOY RICHARD   SAFWAN     NABIL      20672
#
#                     issdttm              expdttm licstatus licensecat  ...  \
# 517302  2007-01-13 11:18:55  2020-12-31 23:59:00  Inactive         RF  ...
#
#                    violdttm violstatus statusdate  \
# 517302  2009-08-21 08:41:56       Fail        NaN
#
#                                   comments              address    city state  \
# 517302  clean floor area of storage Closet  417   Washington ST  Boston    MA
#
#           zip property_id                       location
# 517302  02108    157146.0  (42.355830000, -71.060400000)
#
# [1 rows x 26 columns]

# %%
df_active = df[ df['licstatus'] == 'Active' ]
df_active
# Out:
#                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 619363       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 619364       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 619365       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 619366       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 619367       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# 0        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# 1        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# 2        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# 3        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# 4        Civelis      87059  2013-04-05 12:47:23  2020-12-31 23:59:00
# ...          ...        ...                  ...                  ...
# 619363      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
# 619364      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
# 619365      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
# 619366      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
# 619367      John      27260  2012-02-06 10:50:02  2020-12-31 23:59:00
#
#        licstatus licensecat  ...             violdttm violstatus  \
# 0         Active         FS  ...  2013-02-15 12:19:42       Fail
# 1         Active         FS  ...  2013-02-15 12:19:42       Fail
# 2         Active         FS  ...  2013-02-15 12:19:42       Fail
# 3         Active         FS  ...  2013-02-15 12:19:42       Fail
# 4         Active         FS  ...  2013-02-15 12:19:42       Fail
# ...          ...        ...  ...                  ...        ...
# 619363    Active         FT  ...  2019-10-04 10:47:22       Pass
# 619364    Active         FT  ...  2020-03-11 13:53:43       Pass
# 619365    Active         FT  ...  2020-03-11 13:53:43       Pass
# 619366    Active         FT  ...  2020-03-11 13:53:43       Pass
# 619367    Active         FT  ...  2020-03-11 13:53:43       Pass
#
#                  statusdate  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 619363  2019-10-07 08:34:04
# 619364  2020-03-13 08:40:41
# 619365  2020-03-13 08:40:41
# 619366  2020-03-13 08:40:41
# 619367  2020-03-13 08:40:41
#
#                                                  comments  \
# 0                             Provide glass storage rack.
# 1       Provide dish rack over 3 bay sink to replace m...
# 2               Provide dish washer at ware washing area.
# 3                           Provide mop sink at basement.
# 4                      No hand sink at Bar Area  provide.
# ...                                                   ...
# 619363  They do not have a high temp thermometer for t...
# 619364  No label on yogurt cups in grab n go case.  Sl...
# 619365               Heavy scorded cutting board. Replace
# 619366  Bulk container blocking access to handsink .Ha...
# 619367                       No soap at handsink. Provide
#
#                     address         city state    zip property_id  \
# 0       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# 1       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# 2       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# 3       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# 4       635   Hyde Park AVE   Roslindale    MA  02131     77476.0
# ...                     ...          ...   ...    ...         ...
# 619363        219   Main ST  Charlestown    MA  02129     88457.0
# 619364        219   Main ST  Charlestown    MA  02129     88457.0
# 619365        219   Main ST  Charlestown    MA  02129     88457.0
# 619366        219   Main ST  Charlestown    MA  02129     88457.0
# 619367        219   Main ST  Charlestown    MA  02129     88457.0
#
#                              location
# 0       (42.278590000, -71.119440000)
# 1       (42.278590000, -71.119440000)
# 2       (42.278590000, -71.119440000)
# 3       (42.278590000, -71.119440000)
# 4       (42.278590000, -71.119440000)
# ...                               ...
# 619363  (42.376540000, -71.065421000)
# 619364  (42.376540000, -71.065421000)
# 619365  (42.376540000, -71.065421000)
# 619366  (42.376540000, -71.065421000)
# 619367  (42.376540000, -71.065421000)
#
# [365620 rows x 26 columns]

# %%
df_active['businessname'].value_counts()
# Out:
# Dunkin Donuts           3689
# Subway                  1858
# The Real Deal           1524
# McDonald's              1159
# Burger King             1087
#                         ...
# Grace Note Coffee          1
# Smashburger No. 1725       1
# Simpli Bar & Bites         1
# M/V Asteria                1
# Chic Chick                 1
# Name: businessname, Length: 3450, dtype: int64

# %% [markdown]
# What do each of the first four businesses get most dinged for?

# %%
df_mccoy.groupby(['businessname'])['comments'].value_counts()
# Out:
# businessname      comments
# BOURBON ST. CAFE                                                                                                                                                                                                                                                                  9
#                   Discontinue use of cardboard on prep tables.                                                                                                                                                                                                                    4
#                   Keep all in use wiping cloths in a sanitizing solution when not in use.                                                                                                                                                                                         4
#                   Keep all wiping cloths in a sanitizing solution when not in use.                                                                                                                                                                                                4
#                   Multiple surfaces contaminated with non potable water due to sprinkler discharge. Clean and disinfect all affected areas. Provide invoice from proffesional cleaning company to health division.                                                                4
#                                                                                                                                                                                                                                                                                  ..
# Xian Rougamo      They have sauces stored on a shelf over the mopsink in the mopsink closet.  The mopsink is considered a soiled area  that is why it is separated from the rest of the kitchen  do not store any food products in the mopsink closet.  (discarded by manager)    2
#                   clean all walls in the kitchen                                                                                                                                                                                                                                  2
#                   clean exterior of the water heater in the kitchen. Clean all cooking equipment in the kitchen.                                                                                                                                                                  2
#                   clean floor area throughout the kitchen. Remove heavy buildup on the floor area.                                                                                                                                                                                2
#                   repair slow draining hand sink                                                                                                                                                                                                                                  2
# Name: comments, Length: 1127, dtype: int64

# %% [markdown]
# ## Back to the Boston Marathon

# %%
bm15 = pd.read_csv("data/marathon_results_2015.csv")
bm16 = pd.read_csv("data/marathon_results_2016.csv")
bm17 = pd.read_csv("data/marathon_results_2017.csv")

bm15 = bm15.drop(columns = 'Unnamed: 0')
bm17 = bm17.drop(columns = 'Unnamed: 0')

bm_df = pd.concat([bm15, bm16, bm17])

# %%
bm_df.head(5)
# Out:
#   Bib                   Name  Age M/F         City State Country Citizen  \
# 0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH     NaN
# 1   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH     NaN
# 2   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN     NaN
# 3  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN     NaN
# 4  10          Korir, Wesley   32   M       Kitale   NaN     KEN     NaN
#
#   Unnamed: 9       5K  ...      30K      35K      40K     Pace Proj Time  \
# 0        NaN  0:14:43  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1        NaN  0:14:43  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2        NaN  0:14:43  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3        NaN  0:14:43  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4        NaN  0:14:43  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
#   Official Time Overall Gender Division Unnamed: 8
# 0       2:09:17       1      1        1        NaN
# 1       2:09:48       2      2        2        NaN
# 2       2:10:22       3      3        3        NaN
# 3       2:10:47       4      4        4        NaN
# 4       2:10:49       5      5        5        NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Now we ask, using just the 2017 data:
#
# (1) What country had the most runners?
# (2) Does this vary between Male and Female runners?

# %%
bm17['Country'].value_counts()
# Out:
# USA    20945
# CAN     1870
# GBR      425
# MEX      285
# CHN      242
#        ...
# KSA        1
# TCA        1
# BUL        1
# AND        1
# SRB        1
# Name: Country, Length: 91, dtype: int64

# %%
# It would be good to eliminate the USA rows since we know most runners will be domestic.

bm17[bm17.Country != "USA"]['Country'].value_counts()
# Out:
# CAN    1870
# GBR     425
# MEX     285
# CHN     242
# GER     226
#        ...
# FLK       1
# AND       1
# NGR       1
# MGL       1
# SMR       1
# Name: Country, Length: 90, dtype: int64

# %%
dont_keep = ["USA", "CAN"]

bm17[bm17.Country.isin(dont_keep)]['Country'].value_counts()
# Out:
# GBR    425
# MEX    285
# CHN    242
# GER    226
# BRA    205
#       ...
# TRI      1
# BUL      1
# KSA      1
# SMR      1
# BDI      1
# Name: Country, Length: 89, dtype: int64

# %%
bm17[~bm17.Country.isin(dont_keep)]['Country'].value_counts()
# Out:
# USA    20945
# CAN     1870
# Name: Country, dtype: int64

# %%
bm17.rename(columns = {"M/F":"MaleFemale"})
# Out:
#          Bib                      Name  Age MaleFemale           City State  \
# 0         11           Kirui, Geoffrey   24          M       Keringet   NaN
# 1         17               Rupp, Galen   30          M       Portland    OR
# 2         23             Osako, Suguru   25          M   Machida-City   NaN
# 3         21          Biwott, Shadrack   32          M  Mammoth Lakes    CA
# 4          9            Chebet, Wilson   31          M       Marakwet   NaN
# ...      ...                       ...  ...        ...            ...   ...
# 26405  25166  Steinbach, Paula Eyvonne   61          F        Ontario    CA
# 26406  25178        Avelino, Andrew R.   25          M   Fayetteville    NC
# 26407  27086           Hantel, Johanna   57          F        Malvern    PA
# 26408  25268              Reilly, Bill   64          M       New York    NY
# 26409  25266             Rigsby, Scott   48          M     Alpharetta    GA
#
#       Country Citizen Unnamed: 9       5K  ...      25K      30K      35K  \
# 0         KEN     NaN        NaN  0:15:25  ...  1:16:59  1:33:01  1:48:19
# 1         USA     NaN        NaN  0:15:24  ...  1:16:59  1:33:01  1:48:19
# 2         JPN     NaN        NaN  0:15:25  ...  1:17:00  1:33:01  1:48:31
# 3         USA     NaN        NaN  0:15:25  ...  1:17:00  1:33:01  1:48:58
# 4         KEN     NaN        NaN  0:15:25  ...  1:16:59  1:33:01  1:48:41
# ...       ...     ...        ...      ...  ...      ...      ...      ...
# 26405     USA     NaN         MI  0:46:44  ...  4:12:06  5:03:08  5:55:18
# 26406     USA     NaN         MI  0:32:03  ...  3:50:19  4:50:01  5:53:48
# 26407     USA     NaN        NaN  0:53:11  ...  4:15:21  5:06:37  6:00:33
# 26408     USA     NaN         MI  0:40:34  ...  4:06:10  5:07:09  6:06:07
# 26409     USA     NaN         MI  0:39:36  ...  4:27:14  5:37:13  6:39:07
#
#            40K     Pace Proj Time Official Time Overall Gender Division
# 0      2:02:53  0:04:57         -       2:09:37       1      1        1
# 1      2:03:14  0:04:58         -       2:09:58       2      2        2
# 2      2:03:38  0:04:59         -       2:10:28       3      3        3
# 3      2:04:35  0:05:03         -       2:12:08       4      4        4
# 4      2:05:00  0:05:04         -       2:12:35       5      5        5
# ...        ...      ...       ...           ...     ...    ...      ...
# 26405  6:46:57  0:16:24         -       7:09:39   26407  11972      344
# 26406  6:54:21  0:16:40         -       7:16:59   26408  14436     4774
# 26407  6:54:38  0:16:47         -       7:19:37   26409  11973      698
# 26408  6:56:08  0:16:49         -       7:20:44   26410  14437     1043
# 26409  7:41:23  0:18:15         -       7:58:14   26411  14438     2553
#
# [26410 rows x 24 columns]

# %%
# bm17['MaleFemale'].value_counts()
list(bm17)
# Out:
# ['Bib',
#  'Name',
#  'Age',
#  'M/F',
#  'City',
#  'State',
#  'Country',
#  'Citizen',
#  'Unnamed: 9',
#  '5K',
#  '10K',
#  '15K',
#  '20K',
#  'Half',
#  '25K',
#  '30K',
#  '35K',
#  '40K',
#  'Pace',
#  'Proj Time',
#  'Official Time',
#  'Overall',
#  'Gender',
#  'Division']

# %%
# Now we look at Men and Women but before we do that we rename that column since M/F will cause trouble. 

bm17.rename(columns = {"M/F":"MaleFemale"}, inplace = True)

# `inplace = True` ensures that the column name is overwritten in bm17 otherwise it is just a temporary name change.

# %%
bm17['MaleFemale'].value_counts()
# Out:
# M    14438
# F    11972
# Name: MaleFemale, dtype: int64

# %%
bm17[bm17.MaleFemale == "F"]['Country'].value_counts()
# Out:
# USA    10157
# CAN      815
# GBR      135
# MEX       95
# CHN       77
#        ...
# TRI        1
# NCA        1
# LAT        1
# BER        1
# GRN        1
# Name: Country, Length: 73, dtype: int64

# %%
bm17[bm17.MaleFemale == "M"]['Country'].value_counts()
# Out:
# USA    10788
# CAN     1055
# GBR      290
# MEX      190
# CHN      165
#        ...
# KSA        1
# SMR        1
# TCA        1
# PAR        1
# JAM        1
# Name: Country, Length: 84, dtype: int64

# %% [markdown]
# Now let us see the average age, average finishing time, and so on. We will use the Mean and the Median.

# %%
list(bm17.columns)
# Out:
# ['Bib',
#  'Name',
#  'Age',
#  'MaleFemale',
#  'City',
#  'State',
#  'Country',
#  'Citizen',
#  'Unnamed: 9',
#  '5K',
#  '10K',
#  '15K',
#  '20K',
#  'Half',
#  '25K',
#  '30K',
#  '35K',
#  '40K',
#  'Pace',
#  'Proj Time',
#  'Official Time',
#  'Overall',
#  'Gender',
#  'Division']

# %%
bm17.rename(columns = {"Official Time":"FinishTime", "Proj Time":"ProjectedTime"}, inplace = True)

bm17.describe().round(0)
# Out:
#            Age  Overall   Gender  Division
# count  26410.0  26410.0  26410.0   26410.0
# mean      43.0  13206.0   6661.0    1589.0
# std       11.0   7624.0   3910.0    1423.0
# min       18.0      1.0      1.0       1.0
# 25%       34.0   6604.0   3302.0     502.0
# 50%       43.0  13206.0   6604.0    1154.0
# 75%       51.0  19809.0   9905.0    2191.0
# max       84.0  26411.0  14438.0    5846.0

# %% [markdown]
# Hmm, why is it not giving us anything more than these four columns? Because the other columns are not stored as numbers. We will have to convert them before we can calculate a mean, etc. But converting wil also involve oe extra step ... they are reporting times in hours, minutes, and seconds but it will have to be either in seconds or minutes.

# %%
bm17['FinishTime'] = pd.to_timedelta(bm17['FinishTime']).astype('timedelta64[s]').astype(int).reset_index()

# %%
# The command that follows will show us how each column is stored. 
# Anything listed as an `object` implies it is stored as something other than a number.

bm17.dtypes
# Out:
# Bib              object
# Name             object
# Age               int64
# MaleFemale       object
# City             object
# State            object
# Country          object
# Citizen          object
# Unnamed: 9       object
# 5K               object
# 10K              object
# 15K              object
# 20K              object
# Half             object
# 25K              object
# 30K              object
# 35K              object
# 40K              object
# Pace             object
# ProjectedTime    object
# FinishTime        int64
# Overall           int64
# Gender            int64
# Division          int64
# dtype: object

# %%
# Now we check the means again with `.describe()`

bm17.describe().round(0)
# Out:
#            Age  FinishTime  Overall   Gender  Division
# count  26410.0     26410.0  26410.0  26410.0   26410.0
# mean      43.0     13204.0  13206.0   6661.0    1589.0
# std       11.0      7624.0   7624.0   3910.0    1423.0
# min       18.0         0.0      1.0      1.0       1.0
# 25%       34.0      6602.0   6604.0   3302.0     502.0
# 50%       43.0     13204.0  13206.0   6604.0    1154.0
# 75%       51.0     19807.0  19809.0   9905.0    2191.0
# max       84.0     26409.0  26411.0  14438.0    5846.0

# %%
# What about averages by MaleFemale?

bm17.groupby('MaleFemale').describe()
# Out:
#                 Age                                                      \
#               count       mean        std   min   25%   50%   75%   max
# MaleFemale
# F           11972.0  39.952974  10.703554  18.0  31.0  40.0  48.0  84.0
# M           14438.0  44.772475  11.533255  18.0  36.0  45.0  53.0  83.0
#
#            FinishTime                ...    Gender          Division  \
#                 count          mean  ...       75%      max    count
# MaleFemale                           ...
# F             11972.0  15474.220097  ...   8980.25  11973.0  11972.0
# M             14438.0  11322.446461  ...  10828.75  14438.0  14438.0
#
#
#                    mean          std  min     25%     50%      75%     max
# MaleFemale
# F           1804.635483  1651.393562  1.0  501.75  1200.5  2853.25  5846.0
# M           1409.823036  1171.840025  1.0  502.25  1116.0  1913.00  4774.0
#
# [2 rows x 40 columns]

# %%
# Maybe seconds was a bad idea. How about if we convert it to Minutes? To hours?

bm17['FinishTimeM'] = bm17['FinishTime']/60 
bm17['FinishTimeH'] = bm17['FinishTime']/3600

# %%
bm17.groupby('MaleFemale').describe().round(0)
# Out:
#                 Age                                           FinishTime  \
#               count  mean   std   min   25%   50%   75%   max      count
# MaleFemale
# F           11972.0  40.0  11.0  18.0  31.0  40.0  48.0  84.0    11972.0
# M           14438.0  45.0  12.0  18.0  36.0  45.0  53.0  83.0    14438.0
#
#                      ... FinishTimeM        FinishTimeH                      \
#                mean  ...         75%    max       count mean  std  min  25%
# MaleFemale           ...
# F           15474.0  ...       350.0  440.0     11972.0  4.0  2.0  0.0  3.0
# M           11322.0  ...       304.0  440.0     14438.0  3.0  2.0  0.0  1.0
#
#
#             50%  75%  max
# MaleFemale
# F           4.0  6.0  7.0
# M           3.0  5.0  7.0
#
# [2 rows x 56 columns]

# %%
bm17.groupby('MaleFemale')['FinishTimeM'].describe().round(0)
# Out:
#               count   mean    std  min    25%    50%    75%    max
# MaleFemale
# F           11972.0  258.0  109.0  0.0  172.0  263.0  350.0  440.0
# M           14438.0  189.0  132.0  0.0   69.0  169.0  304.0  440.0

# %%
bm17.groupby('MaleFemale')['FinishTimeH'].describe().round(0)
# Out:
#               count  mean  std  min  25%  50%  75%  max
# MaleFemale
# F           11972.0   4.0  2.0  0.0  3.0  4.0  6.0  7.0
# M           14438.0   3.0  2.0  0.0  1.0  3.0  5.0  7.0

# %%
import seaborn as sns
sns.set_theme()

# %%
sns.displot(bm17, x = "Age")

# %%
# What if we split it out by Age?

sns.displot(bm17, x = "Age", hue = "MaleFemale", col = "MaleFemale", multiple = "dodge")

# %% [markdown]
# Maybe we organzie this better, by collapsing runners into age categories.

# %%
sns.displot(bm17, x = "Age", hue = "MaleFemale", col = "MaleFemale", multiple = "dodge", bins = 10)

# %%
sns.displot(bm17, x = "Age", hue = "MaleFemale", col = "MaleFemale", multiple = "dodge", bins = 5)

# %% [markdown]
# ### Creating a grouped version of Age

# %%
# Say we want the groups to be <= 20, 21-30, 31-40, 41-50, 51-60, 61-70, 70+

mybins = [0, 21, 31, 41, 51, 61, 71, 100]

mylabels = ["<= 20", "21-30", "31-40", "41-50", "51-60", "61-70", "71+"]

bm17['AgeGrouped'] = pd.cut(bm17['Age'], bins = mybins, labels = mylabels, ordered = True)

# %% [markdown]
# `IMPORTANT:` You need one less label that you have distinct values in the binds. Compare `mybins` to `mylabels`

# %%
# I am using `sort = False` so that we see the number of runners in each age group in ascending order of the age
# groups. If we do not add this the result will be sorted in descending order of the frequencies 

bm17['AgeGrouped'].value_counts(sort = False)
# Out:
# <= 20     293
# 21-30    5031
# 31-40    7023
# 41-50    8004
# 51-60    4771
# 61-70    1186
# 71+       102
# Name: AgeGrouped, dtype: int64

# %% [markdown]
# Now we can mess around with the data more by asking, what is mean and median finishing time by age-group of male versus female runners

# %%
bm17.groupby(['MaleFemale', 'AgeGrouped'])['FinishTimeH'].mean().round(2)
# Out:
# MaleFemale  AgeGrouped
# F           <= 20         4.57
#             21-30         3.86
#             31-40         3.88
#             41-50         4.52
#             51-60         5.25
#             61-70         6.07
#             71+           6.82
# M           <= 20         2.50
#             21-30         2.33
#             31-40         2.40
#             41-50         3.00
#             51-60         3.99
#             61-70         5.27
#             71+           6.22
# Name: FinishTimeH, dtype: float64

# %%
# Means can distort the picture if we have skewed distributions so how about the median instead?
bm17.groupby(['MaleFemale', 'AgeGrouped'])['FinishTimeH'].median().round(2)
# Out:
# MaleFemale  AgeGrouped
# F           <= 20         4.78
#             21-30         3.67
#             31-40         3.69
#             41-50         4.59
#             51-60         5.39
#             61-70         6.23
#             71+           6.77
# M           <= 20         1.73
#             21-30         1.26
#             31-40         1.55
#             41-50         2.60
#             51-60         3.98
#             61-70         5.56
#             71+           6.39
# Name: FinishTimeH, dtype: float64

# %% [markdown]
# Some interesting stuff here in that The fastest average time is in the 21-30 group of both Men and Women, no matter what measure of "average" one takes.

# %%
# Now we pull out some more statistics to see which group has the highest variance 

bm17.groupby(['MaleFemale', 'AgeGrouped'])['FinishTimeH'].aggregate(['median', 'mean', 'std', 'var']).round(2)
# Out:
#                        median  mean   std   var
# MaleFemale AgeGrouped
# F          <= 20         4.78  4.57  1.95  3.79
#            21-30         3.67  3.86  2.07  4.30
#            31-40         3.69  3.88  1.82  3.30
#            41-50         4.59  4.52  1.54  2.38
#            51-60         5.39  5.25  1.27  1.61
#            61-70         6.23  6.07  0.91  0.83
#            71+           6.77  6.82  0.42  0.18
# M          <= 20         1.73  2.50  2.34  5.47
#            21-30         1.26  2.33  2.34  5.46
#            31-40         1.55  2.40  2.18  4.77
#            41-50         2.60  3.00  2.00  4.01
#            51-60         3.98  3.99  1.81  3.28
#            61-70         5.56  5.27  1.43  2.06
#            71+           6.39  6.22  0.93  0.86

# %% [markdown]
# Surprise, surprise, it is the 21-30 group for both Males and Females. The winners are in this age-bracket so we should have expectd this from the outset. Least variability is in the 71+ age-bracket.

# %% [markdown]
# ### How many runners ran in only one of the races but not the others? How many ran in all three?

# %%
# We are creating a new column called `nrow` that will look at unique combinations of Name, M/F, City, and Country 
# and count how many rows do we see per person. The maximum should be 3, indicating these individuals ran in all three
# marathons

bm_df['nrow'] = bm_df.groupby(['Name', 'M/F', 'City', 'Country']).cumcount()+1

# %%
# Now the frequency table ...

bm_df['nrow'].value_counts()
# Out:
# 1    69003
# 2     8712
# 3     1923
# Name: nrow, dtype: int64

# %%
# Were men more likely to run in all three or were women more likely to do so? Answer turns out to be Men. 

bm_df.groupby(['M/F'])['nrow'].value_counts()
# Out:
# M/F  nrow
# F    1       31732
#      2        3710
#      3         714
# M    1       37271
#      2        5002
#      3        1209
# Name: nrow, dtype: int64

# %%
bm_df3 = bm_df[ bm_df['nrow'] == 3 ]

# %%
bm_df3
# Out:
#          Bib                   Name  Age M/F              City State Country  \
# 14        10          Korir, Wesley   34   M            Kitale   NaN     KEN
# 30        37       Ornelas, Zachary   25   M         Ann Arbor    MI     USA
# 36       151  Vangampleare, Stephen   26   M  Colorado Springs    CO     USA
# 62        F4         Deba, Buzunesh   29   F              Arsi   NaN     ETH
# 76       152              Ash, Alan   25   M            Atmore    AL     USA
# ...      ...                    ...  ...  ..               ...   ...     ...
# 26388  25179         Solberg, Bryon   55   M         San Diego    CA     USA
# 26391   6893          Ueda, Akifumi   58   M        Himeji-Shi   NaN     JPN
# 26392  10603        Ferry, J. Alain   45   M            Boston    MA     USA
# 26393  27054     Weisberg, Scott R.   47   M        Birmingham    AL     USA
# 26397  15536     Coffman, Steven D.   69   M     East Sandwich    MA     USA
#
#       Citizen Unnamed: 9       5K  ...      35K      40K     Pace Proj Time  \
# 14        NaN        NaN  0:15:24  ...  1:51:50  2:09:58  0:05:17         -
# 30        NaN        NaN  0:17:10  ...  2:01:02  2:17:33  0:05:32         -
# 36        NaN        NaN  0:17:26  ...  2:01:03  2:18:13  0:05:34         -
# 62        NaN        NaN  0:17:45  ...  2:04:47  2:22:49  0:05:46         -
# 76        NaN        NaN  0:17:42  ...  2:06:04  2:24:37  0:05:49         -
# ...       ...        ...      ...  ...      ...      ...      ...       ...
# 26388     NaN         MI  0:40:07  ...  5:10:04  5:56:53  0:14:23         -
# 26391     NaN        NaN  0:28:48  ...  5:00:22  5:56:59  0:14:39         -
# 26392     NaN        NaN  0:39:15  ...  5:23:30  6:07:21  0:14:45         -
# 26393     NaN        NaN  0:46:41  ...  5:14:52  6:06:43  0:14:47         -
# 26397     NaN        NaN  0:32:14  ...  5:37:23  6:24:02  0:15:21         -
#
#       Official Time Overall Gender Division Unnamed: 8 nrow
# 14          2:18:14      15     15       13        NaN    3
# 30          2:24:40      31     28       24        NaN    3
# 36          2:25:35      37     33       28        NaN    3
# 62          2:30:58      63      7        7        NaN    3
# 76          2:32:25      77     68       57        NaN    3
# ...             ...     ...    ...      ...        ...  ...
# 26388       6:16:56   26390  14421     1535        NaN    3
# 26391       6:24:03   26393  14424     1537        NaN    3
# 26392       6:26:31   26394  14425     2551        NaN    3
# 26393       6:27:10   26395  14426     2552        NaN    3
# 26397       6:42:04   26399  14429      425        NaN    3
#
# [1923 rows x 26 columns]

# %% [markdown]
# ## Et voila, le fin!!
